# %% [markdown]
# <a href="https://colab.research.google.com/github/kanika0216/python-Basics/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### *Bike Details Dataset*
#
# 1. *What is the range of selling prices in the dataset?*
#    - ₹5,000 to ₹7,60,000
#
# 2. *What is the median selling price for bikes in the dataset?*
#    - ₹45,000
#
# 3. *What is the most common seller type?*
#    - Individual
#
# 4. *How many bikes have driven more than 50,000 kilometers?*
#    - 170 bikes
#
# 5. *What is the average km_driven value for each ownership type?*
#    - 1st Owner: 32,816 km
#    - 2nd Owner: 39,288 km
#    - 3rd Owner: 33,292 km
#    - 4th Owner: 3,11,500 km
#
# 6. *What proportion of bikes are from the year 2015 or older?*
#    - 56.6%
#
# 7. *What is the trend of missing values across the dataset?*
#    - *ex_showroom_price* has 435 missing values
#
# 8. *What is the highest ex_showroom_price recorded, and for which bike?*
#    - *Harley-Davidson Street Bob* - ₹12,78,000
#
# 9. *What is the total number of bikes listed by each seller type?*
#    - Individual: 1055
#    - Dealer: 6
#
# ---
#
# ### *Car Sales Dataset*
#
# 10. *What is the average selling price of cars for each dealer?*
#     - Buddy Storbeck's Diesel Service Inc: $27,217
#     - C & M Motors Inc: $28,111
#
# 11. *Which car brand has the highest variation in prices?*
#     - Lincoln
#
# 12. *What is the distribution of car prices for each transmission type?*
#     - Automatic: Mean: $28,248, Std: $13,747
#     - Manual: Mean: $27,914, Std: $15,862
#
# 13. *What is the distribution of car prices across different regions?*
#     - Highest Mean Price: Aurora ($28,334)
#     - Lowest Mean Price: Janesville ($27,833)
#
# 14. *What is the distribution of cars based on body styles?*
#     - SUV: 6,374
#     - Hatchback: 6,128
#
# 15. *How does the average selling price of cars vary by customer gender?*
#     - Male: $28,039
#     - Female: $28,277
#
# 16. *What is the distribution of car prices by region, and how does the number of cars sold vary by region?*
#     - Austin: 4,135 cars
#     - Janesville: 3,821 cars
#
# 17. *How does the average car price differ between cars with different engine sizes?*
#     - Double Overhead Camshaft: $28,248
#     - Overhead Camshaft: $27,914
#
# 18. *How do car prices vary based on the customer’s annual income bracket?*
#     - Low Income: $27,884
#     - Middle Income: $28,563
#
# 19. *What are the top 5 car models with the highest number of sales?*
#     - Diamante: 418
#     - Silhouette: 411
#     - Prizm: 411
#     - Passat: 391
#     - Ram Pickup: 383
#
# ---
#
# ### *Amazon Sales Dataset*
#
# 20. *What is the average rating for each product category?*
#     - Tablets: ⭐4.6
#     - Memory Components: ⭐4.5
#
# 21. *What are the top rating_count products by category?*
#     - Fire-Boltt Ninja Call Pro Plus Smartwatch
#
# 22. *What is the distribution of discounted prices vs. actual prices?*
#     - Mean Discounted Price: ₹500-₹2000
#     - Mean Actual Price: ₹1500-₹5000
#
# 23. *How does the average discount percentage vary across categories?*
#     - Keyboards: 32%
#     - Mouse Pads: 61%
#
# 24. *What are the most popular product names?*
#     - Fire-Boltt Smartwatches
#     - AmazonBasics Lightning Cable
#
# 25. *What are the most popular product keywords?*
#     - USB, Charging, Fast, Cable
#
# 26. *What are the most popular product reviews?*
#     - "Satisfied", "Value for Money", "Good Product"
#
# 27. *What is the correlation between discounted_price and rating?*
#     - 0.12 (Weak correlation)
#
# 28. *What are the Top 5 categories based on the highest ratings?*
#     - Tablets, Memory Components, Streaming Devices
#
# 29. *Identify any potential areas for improvement or optimization based on the data analysis.*
#     - 1 missing value in rating, 2 in rating count
#
# ---
#
# ### *Spotify Dataset*
#
# 30. *Are there any missing values or duplicates?*
#     - No missing values
#     - 27 duplicate rows
#
# 31. *What is the distribution of popularity among the tracks in the dataset?*
#     - Most tracks have a popularity score between 60-100
#
# 32. *Is there any relationship between the popularity and the duration of tracks?*
#     - No strong correlation
#
# 33. *Which artist has the highest number of tracks in the dataset?*
#     - Drake (20 tracks)
#
# 34. *What are the top 5 least popular tracks in the dataset?*
#     - Pressa - Attachments (Popularity: 29)
#     - Justin Bieber - Intentions (Popularity: 35)
#
# 35. *Among the top 5 most popular artists, which artist has the highest popularity on average?*
#     - 21 Savage (84.2)
#     - Travis Scott (87.0)
#
# 36. *For the top 5 most popular artists, what are their most popular tracks?*
#     - 21 Savage - redrum (Popularity: 96)
#     - Drake - Rich Baby Daddy (Popularity: 92)
#     - Travis Scott - FE!N (Popularity: 93)
#
# 37. *Does the duration of tracks vary significantly across different artists?*
#     - Yes, some artists have longer songs on average
#
# 38. *How does the distribution of track popularity vary for different artists?*
#     - 21 Savage & Travis Scott have consistently high popularity
